# %%
import pandas as pd
import numpy as np
import scipy
from scipy.stats import norm
#import datetime
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta
import csv
import time

from yahooquery import Ticker


#import pandas_datareader.data as data
#import yfinance as yf


#yf.pdr_override()
from scipy import stats


import mibian

import sys

np.seterr(divide='ignore', invalid='ignore')

import xlwings as xw

# %%
wb = xw.Book("daily.xlsm")
sht2 = wb.sheets['options_chain']
sht3 = wb.sheets['ticker_list']

# %%
shtlist= sht3.range('A1').options(pd.DataFrame, 
                             header=False,
                             index=False, 
                             expand='table').value

# %%
stonks=shtlist.iloc[1:,0].tolist()

# %%
stonks
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'TSLA',
#  'GOOG',
#  'GOOGL',
#  'META',
#  'NVDA',
#  'PEP',
#  'AVGO',
#  'COST',
#  'CSCO',
#  'CMCSA',
#  'ADBE',
#  'INTC',
#  'TMUS',
#  'TXN',
#  'QCOM',
#  'AMD',
#  'AMGN',
#  'HON',
#  'INTU',
#  'AMAT',
#  'MDLZ',
#  'ADP',
#  'QQQ',
#  'KO',
#  'SBUX',
#  'WMT',
#  'JNJ',
#  'PG',
#  'UVXY',
#  'SPY',
#  'HD',
#  'MU']

# %%
stocklist = stonks

# %%
t1 = Ticker(stonks, asynchronous=True)

# %%
df = pd.DataFrame()
df = t1.option_chain

# %%
df.shape
# Out:
# (53578, 14)

# %%
df.head()
# Out:
#                                    contractSymbol  strike currency  lastPrice  \
# symbol expiration optionType
# AAPL   2023-01-13 calls       AAPL230113C00050000    50.0      USD      79.15
#                   calls       AAPL230113C00055000    55.0      USD      74.75
#                   calls       AAPL230113C00060000    60.0      USD      69.65
#                   calls       AAPL230113C00065000    65.0      USD      65.15
#                   calls       AAPL230113C00070000    70.0      USD      60.70
#
#                                 change  percentChange  volume  openInterest  \
# symbol expiration optionType
# AAPL   2023-01-13 calls      -1.049995      -1.309221    38.0          27.0
#                   calls      -0.050003      -0.066849     2.0           3.0
#                   calls       3.599998       5.450414     2.0           3.0
#                   calls       4.350002       7.154609     1.0           2.0
#                   calls       0.900002       1.505019     2.0           2.0
#
#                                 bid    ask contractSize       lastTradeDate  \
# symbol expiration optionType
# AAPL   2023-01-13 calls       80.60  80.80      REGULAR 2023-01-10 17:27:18
#                   calls       75.65  75.95      REGULAR 2023-01-10 15:02:47
#                   calls       70.60  70.95      REGULAR 2023-01-10 14:46:10
#                   calls       65.65  65.90      REGULAR 2023-01-10 18:50:44
#                   calls       60.60  60.95      REGULAR 2023-01-10 14:37:01
#
#                               impliedVolatility  inTheMoney
# symbol expiration optionType
# AAPL   2023-01-13 calls                4.312505        True
#                   calls                3.906250        True
#                   calls                3.359377        True
#                   calls                3.031252        True
#                   calls                2.734378        True

# %%
df.reset_index(inplace=True)

# %%
#df.loc[df['symbol'] == 'MSFT']

# %%
stocks=df.symbol.unique().tolist() 
stocks2 = Ticker(stocks, asynchronous=True)

# %%
def getquotetoday(symbol):
        tk= Ticker(symbol).price
        quote=tk[symbol]['regularMarketPrice']
        return quote

# %%
start = time.time()


L2=list([getquotetoday(item) for item in stocks])


end = time.time()
print(end - start)
# Out:
# 4.85326886177063

# %%
d = dict(zip(stocks,L2))

# %%
df['stock_price'] = df['symbol'].map(d)

# %%
df
# Out:
#       symbol expiration optionType       contractSymbol  strike currency  \
# 0       AAPL 2023-01-13      calls  AAPL230113C00050000    50.0      USD
# 1       AAPL 2023-01-13      calls  AAPL230113C00055000    55.0      USD
# 2       AAPL 2023-01-13      calls  AAPL230113C00060000    60.0      USD
# 3       AAPL 2023-01-13      calls  AAPL230113C00065000    65.0      USD
# 4       AAPL 2023-01-13      calls  AAPL230113C00070000    70.0      USD
# ...      ...        ...        ...                  ...     ...      ...
# 53573    WMT 2025-01-17       puts   WMT250117P00190000   190.0      USD
# 53574    WMT 2025-01-17       puts   WMT250117P00195000   195.0      USD
# 53575    WMT 2025-01-17       puts   WMT250117P00200000   200.0      USD
# 53576    WMT 2025-01-17       puts   WMT250117P00210000   210.0      USD
# 53577    WMT 2025-01-17       puts   WMT250117P00220000   220.0      USD
#
#        lastPrice    change  percentChange  volume  openInterest    bid    ask  \
# 0          79.15 -1.049995      -1.309221    38.0          27.0  80.60  80.80
# 1          74.75 -0.050003      -0.066849     2.0           3.0  75.65  75.95
# 2          69.65  3.599998       5.450414     2.0           3.0  70.60  70.95
# 3          65.15  4.350002       7.154609     1.0           2.0  65.65  65.90
# 4          60.70  0.900002       1.505019     2.0           2.0  60.60  60.95
# ...          ...       ...            ...     ...           ...    ...    ...
# 53573      40.24  0.000000       0.000000     1.0           1.0  45.70  47.90
# 53574      44.25  0.000000       0.000000     1.0           0.0  50.10  52.80
# 53575      55.20  4.330002       8.511897     3.0           0.0  54.00  56.50
# 53576      59.90  0.000000       0.000000     0.0           0.0  62.50  66.50
# 53577      78.00  0.000000       0.000000     4.0           4.0  73.30  77.15
#
#       contractSize       lastTradeDate  impliedVolatility  inTheMoney  \
# 0          REGULAR 2023-01-10 17:27:18           4.312505        True
# 1          REGULAR 2023-01-10 15:02:47           3.906250        True
# 2          REGULAR 2023-01-10 14:46:10           3.359377        True
# 3          REGULAR 2023-01-10 18:50:44           3.031252        True
# 4          REGULAR 2023-01-10 14:37:01           2.734378        True
# ...            ...                 ...                ...         ...
# 53573      REGULAR 2022-11-22 15:11:37           0.173440        True
# 53574      REGULAR 2022-11-22 15:11:37           0.182015        True
# 53575      REGULAR 2023-01-10 18:52:54           0.161080        True
# 53576      REGULAR 2022-12-07 14:30:17           0.178414        True
# 53577      REGULAR 2023-01-05 17:17:59           0.212898        True
#
#        stock_price
# 0           130.73
# 1           130.73
# 2           130.73
# 3           130.73
# 4           130.73
# ...            ...
# 53573       144.86
# 53574       144.86
# 53575       144.86
# 53576       144.86
# 53577       144.86
#
# [53578 rows x 18 columns]

# %%
def optionBS_price(optionType,S, K, sigma, dte):
    '''optionType=call or put, S=stock_price,K=strike, sigma=newMeanSigma, dte=dte .'''
    r=0
    t=dte/365
    d1 = np.multiply( 1. / sigma * np.divide(1., np.sqrt(t)),
        np.log(S/K) + (r + sigma**2 / 2.) * t  )
    d2 = d1 - sigma * np.sqrt(t)
    
    if optionType=="calls":
        C = np.multiply(S, norm.cdf(d1)) - \
        np.multiply(norm.cdf(d2) * K, np.exp(-r * t))
        return C
       
    if optionType=="puts":
        P = -np.multiply(S, norm.cdf(-d1)) + \
        np.multiply(norm.cdf(-d2) * K, np.exp(-r * t))
        return P

# %%
df['V/OI']= df['volume'].astype('float')/df['openInterest']
df['contractSymbol'] = df['contractSymbol'].astype(str)

df[['bid', 'ask', 'strike']] = df[['bid', 'ask', 'strike']].apply(pd.to_numeric)
df['mark'] = (df['bid'] + df['ask']) / 2 # Calculate the midpoint of the bid-ask

        
df.insert(3, 'Distance OTM', df['stock_price'] - df['strike'])
df['Value'] = df['openInterest']*df['lastPrice']*100
df['Dist/Price'] = -df['Distance OTM'] / df['stock_price'] 

df['dte'] = (df['expiration'] - datetime.today()).dt.days 



df = df.drop(columns = ['contractSize', 'currency', 'change', 'percentChange', 'lastTradeDate'])

# %%
df.head()
# Out:
#   symbol expiration optionType  Distance OTM       contractSymbol  strike  \
# 0   AAPL 2023-01-13      calls         80.73  AAPL230113C00050000    50.0
# 1   AAPL 2023-01-13      calls         75.73  AAPL230113C00055000    55.0
# 2   AAPL 2023-01-13      calls         70.73  AAPL230113C00060000    60.0
# 3   AAPL 2023-01-13      calls         65.73  AAPL230113C00065000    65.0
# 4   AAPL 2023-01-13      calls         60.73  AAPL230113C00070000    70.0
#
#    lastPrice  volume  openInterest    bid    ask  impliedVolatility  \
# 0      79.15    38.0          27.0  80.60  80.80           4.312505
# 1      74.75     2.0           3.0  75.65  75.95           3.906250
# 2      69.65     2.0           3.0  70.60  70.95           3.359377
# 3      65.15     1.0           2.0  65.65  65.90           3.031252
# 4      60.70     2.0           2.0  60.60  60.95           2.734378
#
#    inTheMoney  stock_price      V/OI    mark     Value  Dist/Price  dte
# 0        True       130.73  1.407407  80.700  213705.0   -0.617532    2
# 1        True       130.73  0.666667  75.800   22425.0   -0.579286    2
# 2        True       130.73  0.666667  70.775   20895.0   -0.541039    2
# 3        True       130.73  0.500000  65.775   13030.0   -0.502792    2
# 4        True       130.73  1.000000  60.775   12140.0   -0.464545    2

# %%
df['Abs_Dist/Price'] = df['Dist/Price'].abs()

# %%
#def gamma(row):
 #   return  mibian.BS([row['stock_price'], row['strike'],0,row['dte']], volatility=(row['impliedVolatility']*100)).gamma
        
#with np.errstate(divide='ignore', invalid='ignore'):
 #   df['gamma'] = df.apply(lambda x: gamma(x), axis=1)

# %%
#def vega(row):
 #   return  mibian.BS([row['stock_price'], row['strike'],0,row['dte']], volatility=(row['impliedVolatility']*100)).vega

#with np.errstate(divide='ignore', invalid='ignore'):        
 #   df['vega'] = df.apply(lambda x: vega(x), axis=1)

# %%
#df['vega_per'] = df['vega'] / df['ask'] 
#df['IV_inver'] = 1 / df['impliedVolatility']

# %%
d = datetime.today() - timedelta(days=30)
yq_data = stocks2.history(start=d, interval='1d')

# %%
yq_data.reset_index(inplace=True)

# %%
yq_data
# Out:
#     symbol        date        open         low       close        high  \
# 0     AAPL  2022-12-12  142.699997  141.059998  144.490005  144.500000
# 1     AAPL  2022-12-13  149.500000  144.240005  145.470001  149.970001
# 2     AAPL  2022-12-14  145.350006  141.160004  143.210007  146.660004
# 3     AAPL  2022-12-15  141.110001  136.029999  136.500000  141.800003
# 4     AAPL  2022-12-16  136.690002  133.729996  134.509995  137.649994
# ..     ...         ...         ...         ...         ...         ...
# 695    WMT  2023-01-04  143.419998  142.070007  143.759995  144.050003
# 696    WMT  2023-01-05  143.460007  142.649994  143.270004  144.130005
# 697    WMT  2023-01-06  144.600006  144.240005  146.779999  147.550003
# 698    WMT  2023-01-09  146.320007  144.800003  144.949997  147.860001
# 699    WMT  2023-01-10  144.940002  143.729996  144.860001  145.449997
#
#         volume    adjclose  dividends
# 0     70462700  144.490005        0.0
# 1     93886200  145.470001        0.0
# 2     82291200  143.210007        0.0
# 3     98931900  136.500000        0.0
# 4    160156900  134.509995        0.0
# ..         ...         ...        ...
# 695    4446100  143.759995        0.0
# 696    4424800  143.270004        0.0
# 697    7076300  146.779999        0.0
# 698    5918900  144.949997        0.0
# 699    3989900  144.860001        0.0
#
# [700 rows x 9 columns]

# %%
today_volume = yq_data.groupby('symbol')['volume'].last().to_dict()

# %%
yq_data = yq_data.drop(columns = ['open', 'low', 'close', 'high','dividends'])# 'dividends'])

# %%
yq_data = yq_data.assign(logret=np.log(yq_data.adjclose).groupby(yq_data.symbol).diff())

# %%
yq_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   symbol    700 non-null    object
#  1   date      700 non-null    object
#  2   volume    700 non-null    int64
#  3   adjclose  700 non-null    float64
#  4   logret    665 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 27.5+ KB

# %%
yq_data2 =pd.DataFrame()

yq_data2 = yq_data.groupby('symbol').agg(np.std, ddof=1)

# %%
yq_data2
# Out:
#         date        volume   adjclose    logret
# symbol
# AAPL     NaN  2.122729e+07   6.002265  0.021918
# ADBE     NaN  2.321590e+06   4.664292  0.021318
# ADP      NaN  7.106014e+05   8.536299  0.016216
# AMAT     NaN  2.404099e+06   5.377895  0.031112
# AMD      NaN  1.269487e+07   2.566681  0.028930
# AMGN     NaN  1.656118e+06   4.579772  0.011971
# AMZN     NaN  2.064918e+07   2.974266  0.023441
# AVGO     NaN  1.097191e+06  11.286079  0.020715
# CMCSA    NaN  1.230845e+07   1.324971  0.017104
# COST     NaN  1.083673e+06  12.739472  0.020658
# CSCO     NaN  1.187048e+07   0.806948  0.011231
# GOOG     NaN  7.264200e+06   2.492335  0.018704
# GOOGL    NaN  9.117864e+06   2.612922  0.018557
# HD       NaN  1.878369e+06   5.661740  0.011751
# HON      NaN  1.346726e+06   2.799230  0.014157
# INTC     NaN  1.337203e+07   1.205189  0.021001
# INTU     NaN  7.322624e+05  13.234381  0.025978
# JNJ      NaN  3.582293e+06   1.563052  0.009292
# KO       NaN  5.827422e+06   0.627643  0.009342
# MDLZ     NaN  3.134013e+06   0.659905  0.009998
# META     NaN  1.121138e+07   5.538809  0.026021
# MSFT     NaN  1.560031e+07   9.875269  0.018860
# MU       NaN  6.822221e+06   2.695470  0.026828
# NVDA     NaN  8.633894e+06  12.554120  0.036326
# PEP      NaN  2.827816e+06   1.892383  0.008747
# PG       NaN  3.451870e+06   1.039660  0.008980
# QCOM     NaN  2.236349e+06   4.691467  0.025631
# QQQ      NaN  1.201379e+07   7.810110  0.015789
# SBUX     NaN  2.592690e+06   2.900011  0.014032
# SPY      NaN  2.070222e+07   6.486009  0.012113
# TMUS     NaN  3.222682e+06   3.284602  0.013402
# TSLA     NaN  3.609583e+07  19.662910  0.058143
# TXN      NaN  1.887359e+06   5.532697  0.019995
# UVXY     NaN  1.183777e+07   0.450811  0.043112
# WMT      NaN  2.291470e+06   1.865873  0.010492

# %%
yq_data2['stdev'] = yq_data2['logret'] * 252**.5

# %%
yq_data2.reset_index(inplace=True)

# %%
vol_map = dict(yq_data2[['symbol','stdev']].values)

# %%
d90 = datetime.today() - timedelta(days=90)
yq_data90x = stocks2.history(start=d90, interval='1d')

yq_data90x.reset_index(inplace=True)

yq_data90 = yq_data90x.drop(columns = ['open', 'low', 'close', 'high', 'dividends'])
yq_data90 = yq_data90.assign(logret=np.log(yq_data90.adjclose).groupby(yq_data90.symbol).diff()) 

yq_data2_90 =pd.DataFrame()

yq_data2_90 = yq_data90.groupby('symbol').agg(np.std, ddof=1) 

yq_data2_90['stdev'] = yq_data2_90['logret'] * 252**.5
yq_data2_90.reset_index(inplace=True)
vol_map90 = dict(yq_data2_90[['symbol','stdev']].values)

# %%
yq_data90
# Out:
#      symbol        date     volume    adjclose    logret
# 0      AAPL  2022-10-13  113224000  142.753204       NaN
# 1      AAPL  2022-10-14   88598000  138.150833 -0.032771
# 2      AAPL  2022-10-17   85250900  142.174164  0.028707
# 3      AAPL  2022-10-18   99136600  143.511932  0.009365
# 4      AAPL  2022-10-19   61758300  143.621750  0.000765
# ...     ...         ...        ...         ...       ...
# 2130    WMT  2023-01-04    4446100  143.759995  0.001114
# 2131    WMT  2023-01-05    4424800  143.270004 -0.003414
# 2132    WMT  2023-01-06    7076300  146.779999  0.024204
# 2133    WMT  2023-01-09    5918900  144.949997 -0.012546
# 2134    WMT  2023-01-10    3989900  144.860001 -0.000621
#
# [2135 rows x 5 columns]

# %%
yq_data3 =pd.DataFrame()

yq_data3 = yq_data.groupby('symbol')['volume'].agg(np.mean).to_dict()

# %%
df['h_volume'] = df.symbol.map(yq_data3)

# %%
df['volume_today'] = df.symbol.map(today_volume)

# %%
df['hvol_30'] = df.symbol.map(vol_map)

# %%
df['hvol_90'] = df.symbol.map(vol_map90)

# %%
df['vT/vH'] =  df['volume_today'] / df['h_volume']

# %%
df['mean_sigma'] =  .65*df['hvol_30'] + .2*df['hvol_90'] +.15*df['impliedVolatility'] 
df['ba_spread'] =  ((df['ask'] - df['bid'])/df['ask']).abs()

# %%
df = df[df['ba_spread'] > 0]

# %%
df['option_bs_mean_S'] = df.apply(lambda row: optionBS_price(row['optionType'],row['stock_price'], row['strike'],row['mean_sigma'],row['dte']), axis=1)

# %%
df['EOM']  =  pd.to_datetime(pd.Period(date.today(),freq='M').end_time.date()).floor('D')

# %%
df.head()
# Out:
#   symbol expiration optionType  Distance OTM       contractSymbol  strike  \
# 0   AAPL 2023-01-13      calls         80.73  AAPL230113C00050000    50.0
# 1   AAPL 2023-01-13      calls         75.73  AAPL230113C00055000    55.0
# 2   AAPL 2023-01-13      calls         70.73  AAPL230113C00060000    60.0
# 3   AAPL 2023-01-13      calls         65.73  AAPL230113C00065000    65.0
# 4   AAPL 2023-01-13      calls         60.73  AAPL230113C00070000    70.0
#
#    lastPrice  volume  openInterest    bid  ...  Abs_Dist/Price  h_volume  \
# 0      79.15    38.0          27.0  80.60  ...        0.617532  85096720
# 1      74.75     2.0           3.0  75.65  ...        0.579286  85096720
# 2      69.65     2.0           3.0  70.60  ...        0.541039  85096720
# 3      65.15     1.0           2.0  65.65  ...        0.502792  85096720
# 4      60.70     2.0           2.0  60.60  ...        0.464545  85096720
#
#    volume_today   hvol_30   hvol_90     vT/vH  mean_sigma  ba_spread  \
# 0      63803400  0.347939  0.403111  0.749775    0.953658   0.002475
# 1      63803400  0.347939  0.403111  0.749775    0.892720   0.003950
# 2      63803400  0.347939  0.403111  0.749775    0.810689   0.004933
# 3      63803400  0.347939  0.403111  0.749775    0.761470   0.003794
# 4      63803400  0.347939  0.403111  0.749775    0.716939   0.005742
#
#    option_bs_mean_S        EOM
# 0             80.73 2023-01-31
# 1             75.73 2023-01-31
# 2             70.73 2023-01-31
# 3             65.73 2023-01-31
# 4             60.73 2023-01-31
#
# [5 rows x 29 columns]

# %%
df['value_plus'] = (df['option_bs_mean_S']/df.mark)-1

# %%
from MACD import rollavg
Price_roll = rollavg(stocks,yq_data90x,30,"Price",MACD_P=True)

# %%
Volume_roll = rollavg(stocks,yq_data90x,30,"Volume",MACD_V=True)

# %%
df['MACD_P'] = df['symbol'].map(Price_roll)
df['MACD_V'] = df['symbol'].map(Volume_roll)

# %%
df.head()
# Out:
#   symbol expiration optionType  Distance OTM       contractSymbol  strike  \
# 0   AAPL 2023-01-13      calls         80.73  AAPL230113C00050000    50.0
# 1   AAPL 2023-01-13      calls         75.73  AAPL230113C00055000    55.0
# 2   AAPL 2023-01-13      calls         70.73  AAPL230113C00060000    60.0
# 3   AAPL 2023-01-13      calls         65.73  AAPL230113C00065000    65.0
# 4   AAPL 2023-01-13      calls         60.73  AAPL230113C00070000    70.0
#
#    lastPrice  volume  openInterest    bid  ...   hvol_30   hvol_90     vT/vH  \
# 0      79.15    38.0          27.0  80.60  ...  0.347939  0.403111  0.749775
# 1      74.75     2.0           3.0  75.65  ...  0.347939  0.403111  0.749775
# 2      69.65     2.0           3.0  70.60  ...  0.347939  0.403111  0.749775
# 3      65.15     1.0           2.0  65.65  ...  0.347939  0.403111  0.749775
# 4      60.70     2.0           2.0  60.60  ...  0.347939  0.403111  0.749775
#
#    mean_sigma  ba_spread  option_bs_mean_S        EOM  value_plus    MACD_P  \
# 0    0.953658   0.002475             80.73 2023-01-31    0.000372  0.997316
# 1    0.892720   0.003950             75.73 2023-01-31   -0.000923  0.997316
# 2    0.810689   0.004933             70.73 2023-01-31   -0.000636  0.997316
# 3    0.761470   0.003794             65.73 2023-01-31   -0.000684  0.997316
# 4    0.716939   0.005742             60.73 2023-01-31   -0.000740  0.997316
#
#      MACD_V
# 0  0.951105
# 1  0.951105
# 2  0.951105
# 3  0.951105
# 4  0.951105
#
# [5 rows x 32 columns]

# %%
#df.loc[(df['symbol'] == 'GSK') & (df['expiration'] == '2021-08-20') & (df['strike'] ==29), ['strike', 'ask','impliedVolatility','stock_price','dte','gamma','vega']]

# %%
#df.loc[(df['symbol'] == 'HOL')  & (df['strike'] ==10) & (df['expiration'] =='2021-06-18'),['optionType','hvol','hvol90','impliedVolatility']]

# %%
sht2.clear_contents()

# %%
sht2["A1"].options(pd.DataFrame, index=False, header=1,expand='table').value = df

# %%
cond1 = df.lastPrice <= 75
cond2 = df.value_plus <= -.15
cond3 = df.expiration <= pd.to_datetime(pd.Period(date.today(),freq='M').end_time.date()).floor('D')
cond4 = df.volume > 500
cond5 = df.ask >= 30
cond6 = df.optionType = 'calls'

# %%
df_filtered = df.query("lastPrice<=75 & openInterest >=500 & expiration <= EOM & openInterest > 500  & ask >= 30 & value_plus <= -.15 ")

# %%
df_filtered2= df_filtered[['symbol','expiration','strike','lastPrice','bid','ask','option_bs_mean_S','stock_price','value_plus']].loc[(df_filtered.optionType == "calls")].sort_values('value_plus').head(25)

# %%
df_filtered2['share_purchase_cost'] = df_filtered2.stock_price *100
df_filtered2['short_call_income'] = df_filtered2.bid *100
df_filtered2['net_income'] = df_filtered2['share_purchase_cost'] -df_filtered2['short_call_income']

# %%
df_filtered2
# Out:
#       symbol expiration  strike  lastPrice    bid    ask  option_bs_mean_S  \
# 7098    AMZN 2023-01-20  3650.0      37.50  32.90  36.20      1.623219e-15
# 7099    AMZN 2023-01-20  3700.0      31.40  29.00  33.80      1.715101e-16
# 7100    AMZN 2023-01-20  3750.0      29.55  26.40  30.40      1.657165e-17
# 7097    AMZN 2023-01-20  3600.0      37.50  36.15  39.55      1.418947e-14
# 7096    AMZN 2023-01-20  3550.0      42.60  38.70  44.20      1.256420e-13
# 7095    AMZN 2023-01-20  3500.0      45.95  44.70  48.45      2.072530e-12
# 7085    AMZN 2023-01-20  3400.0      56.80  52.20  58.40      1.587920e-10
# 7073    AMZN 2023-01-20  3300.0      67.50  65.35  70.75      4.471012e-08
# 17748  GOOGL 2023-01-20    52.0      69.50  58.90  60.20      3.656869e+01
# 14872   GOOG 2023-01-20    42.0      74.09  68.50  73.30      4.732093e+01
# 14869   GOOG 2023-01-20    39.0      73.95  71.00  75.30      5.029975e+01
# 17754  GOOGL 2023-01-20    58.0      30.70  42.40  43.30      3.044527e+01
#
#        stock_price  value_plus  share_purchase_cost  short_call_income  \
# 7098         89.87   -1.000000               8987.0             3290.0
# 7099         89.87   -1.000000               8987.0             2900.0
# 7100         89.87   -1.000000               8987.0             2640.0
# 7097         89.87   -1.000000               8987.0             3615.0
# 7096         89.87   -1.000000               8987.0             3870.0
# 7095         89.87   -1.000000               8987.0             4470.0
# 7085         89.87   -1.000000               8987.0             5220.0
# 7073         89.87   -1.000000               8987.0             6535.0
# 17748        88.42   -0.385916               8842.0             5890.0
# 14872        89.24   -0.332568               8924.0             6850.0
# 14869        89.24   -0.312375               8924.0             7100.0
# 17754        88.42   -0.289492               8842.0             4240.0
#
#        net_income
# 7098       5697.0
# 7099       6087.0
# 7100       6347.0
# 7097       5372.0
# 7096       5117.0
# 7095       4517.0
# 7085       3767.0
# 7073       2452.0
# 17748      2952.0
# 14872      2074.0
# 14869      1824.0
# 17754      4602.0

# %%
slope = pd.pivot_table(df, index = ['symbol','expiration'], columns='strike', values = 'impliedVolatility', aggfunc='mean').reset_index(level=1)

# %%
slope.reset_index(inplace=True)

# %%
slope.head()
# Out:
# strike symbol expiration  1.0  1.67  2.0  3.0  3.33  3.5  4.0  4.5  ...  \
# 0        AAPL 2023-01-13  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 1        AAPL 2023-01-20  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 2        AAPL 2023-01-27  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 3        AAPL 2023-02-03  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 4        AAPL 2023-02-10  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
#
# strike  4800.0  4850.0  4900.0  4950.0  5000.0  5100.0  5200.0  5300.0  \
# 0          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# strike  5400.0  5500.0
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
#
# [5 rows x 1283 columns]

# %%
def slope_reg(i):
    #for i in range(len(slope.index)):
        slopex=slope.iloc[[i]].dropna(1)
        slopex1 = slopex.T
        x =slopex1.index[2:].to_numpy()
        x=x.astype(float)
        y = slopex1.iloc[2:,0:].to_numpy()
        y = y.ravel()
        y=y.astype(float)
        slopeB = stats.linregress(x, y)
        return slopeB.slope

# %%
slope['slope_reg'] = slope.apply(lambda row: slope_reg(row.name), axis=1)

# %%
slope.head()
# Out:
# strike symbol expiration  1.0  1.67  2.0  3.0  3.33  3.5  4.0  4.5  ...  \
# 0        AAPL 2023-01-13  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 1        AAPL 2023-01-20  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 2        AAPL 2023-01-27  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 3        AAPL 2023-02-03  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 4        AAPL 2023-02-10  NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
#
# strike  4850.0  4900.0  4950.0  5000.0  5100.0  5200.0  5300.0  5400.0  \
# 0          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# strike  5500.0  slope_reg
# 0          NaN  -0.003652
# 1          NaN  -0.001169
# 2          NaN  -0.005774
# 3          NaN  -0.002905
# 4          NaN  -0.004516
#
# [5 rows x 1284 columns]

# %%
slope.groupby(['symbol'])['slope_reg'].mean().to_frame().reset_index().sort_values(['slope_reg'], ascending=False)
# Out:
#    symbol  slope_reg
# 31   UVXY   0.029181
# 11  GOOGL   0.000641
# 25    QQQ  -0.000402
# 1    ADBE  -0.000454
# 15   INTU  -0.000538
# 7    COST  -0.000648
# 2     AMD  -0.000678
# 19   MSFT  -0.000702
# 5    AVGO  -0.000706
# 30    TXN  -0.000790
# 29   TSLA  -0.000832
# 12     HD  -0.001034
# 21   NVDA  -0.001048
# 20   NFLX  -0.001073
# 27    SPY  -0.001211
# 24   QCOM  -0.001322
# 4    AMZN  -0.001339
# 13    HON  -0.001668
# 0    AAPL  -0.001727
# 18   META  -0.001997
# 3    AMGN  -0.002085
# 10   GOOG  -0.002141
# 32    WMT  -0.002996
# 22    PEP  -0.003142
# 23     PG  -0.003298
# 28   TMUS  -0.003528
# 26   SBUX  -0.003723
# 16    JNJ  -0.003764
# 8    CSCO  -0.003983
# 14   INTC  -0.006019
# 9    GILD  -0.007602
# 17     KO  -0.008579
# 6   CMCSA  -0.012342

# %%
slope.groupby(['symbol'])['slope_reg'].apply(lambda x : x.head(3).reset_index(drop = True)).groupby(['symbol']).mean().sort_values(ascending=False).head(20).to_frame().reset_index()
# Out:
#    symbol  slope_reg
# 0    UVXY   0.031989
# 1    CSCO   0.005593
# 2   GOOGL   0.004773
# 3     AMD   0.003896
# 4     QQQ   0.001680
# 5    TSLA   0.000978
# 6    MSFT   0.000649
# 7    ADBE  -0.000251
# 8    QCOM  -0.000474
# 9    INTU  -0.000526
# 10   NVDA  -0.001051
# 11   COST  -0.001503
# 12     HD  -0.001653
# 13   AVGO  -0.001782
# 14   AMZN  -0.002199
# 15    TXN  -0.002379
# 16    HON  -0.002424
# 17   NFLX  -0.002536
# 18   AMGN  -0.002781
# 19   AAPL  -0.003532
